# %%
import pandas as pd
from pathlib import Path

# %%
ticker_path = Path('../nasdaq_screener_1626325644795.csv')

# %%
ticker_df = pd.read_csv(ticker_path).drop(columns=['Name','Last Sale','% Change','Market Cap','Country','IPO Year','Volume','Sector','Industry','Net Change'])
ticker_df
# Out:
#      Symbol
# 0      AACG
# 1       AAL
# 2      AAME
# 3      AAOI
# 4      AAON
# ...     ...
# 4361  ZWRKU
# 4362  ZWRKW
# 4363     ZY
# 4364   ZYNE
# 4365   ZYXI
#
# [4366 rows x 1 columns]

# %%
ticker_df.to_csv(Path('../nasdaq_symbols.csv'))

# %%
def check_ticker(ticker, ticker_csv):
    if ticker in ticker_csv:
        print('Your ticker entry is valid.')

# %%
ticker = 'aapl'
check_ticker(ticker.upper(), ticker_df)
# Out:
#  entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# Check that your ticker is entered correctly!
# ...
